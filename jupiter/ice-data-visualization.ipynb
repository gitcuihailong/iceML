# %%
# Make the output of plotting commands be displayed inline within the notebook
# Basemap: https://anaconda.org/conda-forge/basemap
# Pygrib: https://anaconda.org/conda-forge/pygrib
# If throws error for outdated libpng, use conda install -c conda-forge libpng

# %matplotlib inline 
from mpl_toolkits.basemap import Basemap  # import Basemap matplotlib toolkit
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors
from matplotlib.colors import LinearSegmentedColormap
import pygrib # import pygrib interface to grib_api

# %%
# Open the grib file
grbs = pygrib.open('icedata_2018-03-23T08-54-45_next_6hours.grb2')

# %%
for grb in grbs:
    print(grb)
# Out:
# 1:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201803230000
# 2:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201803230000
# 3:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201803230000
# 4:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201803230000
# 5:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201803230000
# 6:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201803230000
# 7:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201803230000
# 8:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201803230000
# 9:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201803230000
# 10:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201803230000
# 11:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201803230000
# 12:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201803230000
# 13:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201803230000
# 14:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201803230000
# 15:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201803230000
# 16:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 16 hrs:from 201803230000
# 17:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 17 hrs:from 201803230000
# 18:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 18 hrs:from 201803230000
# 19:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 19 hrs:from 201803230000
# 20:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 20 hrs:from 201803230000
# 21:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 21 hrs:from 201803230000
# 22:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 22 hrs:from 201803230000
# 23:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 23 hrs:from 201803230000
# 24:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 24 hrs:from 201803230000
# 25:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 25 hrs:from 201803230000
# 26:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 26 hrs:from 201803230000
# 27:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 27 hrs:from 201803230000
# 28:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 28 hrs:from 201803230000
# 29:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 29 hrs:from 201803230000
# 30:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 30 hrs:from 201803230000
# 31:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 31 hrs:from 201803230000
# 32:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 32 hrs:from 201803230000
# 33:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 33 hrs:from 201803230000
# 34:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 34 hrs:from 201803230000
# 35:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 35 hrs:from 201803230000
# 36:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 36 hrs:from 201803230000
# 37:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 37 hrs:from 201803230000
# 38:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 38 hrs:from 201803230000
# 39:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 39 hrs:from 201803230000
# 40:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 40 hrs:from 201803230000
# 41:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 41 hrs:from 201803230000
# 42:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 42 hrs:from 201803230000
# 43:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 43 hrs:from 201803230000
# 44:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 44 hrs:from 201803230000
# 45:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 45 hrs:from 201803230000
# 46:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 46 hrs:from 201803230000
# 47:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 47 hrs:from 201803230000
# 48:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 48 hrs:from 201803230000
# 49:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 49 hrs:from 201803230000
# 50:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 50 hrs:from 201803230000
# 51:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 51 hrs:from 201803230000
# 52:Sea-ice thickness:m (instant):regular_ll:surface:level 0:fcst time 52 hrs:from 201803230000
# 53:Sea-ice cover:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 1 hrs:from 201803230000
# 54:Sea-ice cover:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 2 hrs:from 201803230000
# 55:Sea-ice cover:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 3 hrs:from 201803230000
# 56:Sea-ice cover:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 4 hrs:from 201803230000
# 57:Sea-ice cover:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 5 hrs:from 201803230000
# 58:Sea-ice cover:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 6 hrs:from 201803230000
# 59:Sea-ice cover:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 7 hrs:from 201803230000
# 60:Sea-ice cover:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 8 hrs:from 201803230000
# 61:Sea-ice cover:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 9 hrs:from 201803230000
# 62:Sea-ice cover:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 10 hrs:from 201803230000
# 63:Sea-ice cover:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 11 hrs:from 201803230000
# 64:Sea-ice cover:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 12 hrs:from 201803230000
# 65:Sea-ice cover:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 13 hrs:from 201803230000
# 66:Sea-ice cover:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 14 hrs:from 201803230000
# 67:Sea-ice cover:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 15 hrs:from 201803230000
# 68:Sea-ice cover:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 16 hrs:from 201803230000
# 69:Sea-ice cover:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 17 hrs:from 201803230000
# 70:Sea-ice cover:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 18 hrs:from 201803230000
# 71:Sea-ice cover:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 19 hrs:from 201803230000
# 72:Sea-ice cover:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 20 hrs:from 201803230000
# 73:Sea-ice cover:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 21 hrs:from 201803230000
# 74:Sea-ice cover:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 22 hrs:from 201803230000
# 75:Sea-ice cover:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 23 hrs:from 201803230000
# 76:Sea-ice cover:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 24 hrs:from 201803230000
# 77:Sea-ice cover:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 25 hrs:from 201803230000
# 78:Sea-ice cover:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 26 hrs:from 201803230000
# 79:Sea-ice cover:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 27 hrs:from 201803230000
# 80:Sea-ice cover:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 28 hrs:from 201803230000
# 81:Sea-ice cover:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 29 hrs:from 201803230000
# 82:Sea-ice cover:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 30 hrs:from 201803230000
# 83:Sea-ice cover:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 31 hrs:from 201803230000
# 84:Sea-ice cover:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 32 hrs:from 201803230000
# 85:Sea-ice cover:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 33 hrs:from 201803230000
# 86:Sea-ice cover:(0 - 1) (instant):regular_ll:surface:level 0:fcst time 34 hrs:from 201803230000
# 87:Sea-ice cover:(0 - 1) (instant):regular_ll:surface:level 0:fcst time
Ice thickness:m (instant):regular_ll:surface:level 0:fcst time 51 hrs:from 201803230000
# 260:Ice thickness:m (instant):regular_ll:surface:level 0:fcst time 52 hrs:from 201803230000

# %%
grb.keys()
# Out:
# ['parametersVersion',
#  'UseEcmfConventions',
#  'GRIBEX_boustrophedonic',
#  'hundred',
#  'globalDomain',
#  'GRIBEditionNumber',
#  'tablesVersionLatest',
#  'grib2divider',
#  'angularPrecision',
#  'missingValue',
#  'ieeeFloats',
#  'isHindcast',
#  'section0Length',
#  'identifier',
#  'discipline',
#  'editionNumber',
#  'totalLength',
#  'sectionNumber',
#  'section1Length',
#  'numberOfSection',
#  'centre',
#  'centreDescription',
#  'subCentre',
#  'tablesVersion',
#  'masterDir',
#  'localTablesVersion',
#  'significanceOfReferenceTime',
#  'year',
#  'month',
#  'day',
#  'hour',
#  'minute',
#  'second',
#  'dataDate',
#  'julianDay',
#  'dataTime',
#  'productionStatusOfProcessedData',
#  'typeOfProcessedData',
#  'selectStepTemplateInterval',
#  'selectStepTemplateInstant',
#  'stepType',
#  'setCalendarId',
#  'deleteCalendarId',
#  'is_uerra',
#  'sectionNumber',
#  'grib2LocalSectionPresent',
#  'sectionNumber',
#  'gridDescriptionSectionPresent',
#  'section3Length',
#  'numberOfSection',
#  'sourceOfGridDefinition',
#  'numberOfDataPoints',
#  'numberOfOctectsForNumberOfPoints',
#  'interpretationOfNumberOfPoints',
#  'PLPresent',
#  'gridDefinitionTemplateNumber',
#  'gridDefinitionDescription',
#  'shapeOfTheEarth',
#  'scaleFactorOfRadiusOfSphericalEarth',
#  'scaledValueOfRadiusOfSphericalEarth',
#  'scaleFactorOfEarthMajorAxis',
#  'scaledValueOfEarthMajorAxis',
#  'scaleFactorOfEarthMinorAxis',
#  'scaledValueOfEarthMinorAxis',
#  'radius',
#  'Ni',
#  'Nj',
#  'basicAngleOfTheInitialProductionDomain',
#  'mBasicAngle',
#  'angleMultiplier',
#  'mAngleMultiplier',
#  'subdivisionsOfBasicAngle',
#  'angleDivisor',
#  'latitudeOfFirstGridPoint',
#  'longitudeOfFirstGridPoint',
#  'resolutionAndComponentFlags',
#  'resolutionAndComponentFlags1',
#  'resolutionAndComponentFlags2',
#  'iDirectionIncrementGiven',
#  'jDirectionIncrementGiven',
#  'uvRelativeToGrid',
#  'resolutionAndComponentFlags6',
#  'resolutionAndComponentFlags7',
#  'resolutionAndComponentFlags8',
#  'ijDirectionIncrementGiven',
#  'latitudeOfLastGridPoint',
#  'longitudeOfLastGridPoint',
#  'iDirectionIncrement',
#  'jDirectionIncrement',
#  'scanningMode',
#  'iScansNegatively',
#  'jScansPositively',
#  'jPointsAreConsecutive',
#  'alternativeRowScanning',
#  'iScansPositively',
#  'scanningMode5',
#  'scanningMode6',
#  'scanningMode7',
#  'scanningMode8',
#  'g2grid',
#  'latitudeOfFirstGridPointInDegrees',
#  'longitudeOfFirstGridPointInDegrees',
#  'latitudeOfLastGridPointInDegrees',
#  'longitudeOfLastGridPointInDegrees',
#  'iDirectionIncrementInDegrees',
#  'jDirectionIncrementInDegrees',
#  'latLonValues',
#  'latitudes',
#  'longitudes',
#  'distinctLatitudes',
#  'distinctLongitudes',
#  'gridType',
#  'sectionNumber',
#  'section4Length',
#  'numberOfSection',
#  'NV',
#  'neitherPresent',
#  'productDefinitionTemplateNumber',
#  'genVertHeightCoords',
#  'parameterCategory',
#  'parameterNumber',
#  'parameterUnits',
#  'parameterName',
#  'typeOfGeneratingProcess',
#  'backgroundProcess',
#  'generatingProcessIdentifier',
#  'hoursAfterDataCutoff',
#  'minutesAfterDataCutoff',
#  'indicatorOfUnitOfTimeRange',
#  'stepUnits',
#  'forecastTime',
#  'startStep',
#  'endStep',
#  'stepRange',
#  'stepTypeInternal',
#  'validityDate',
#  'validityTime',
#  'typeOfFirstFixedSurface',
#  'unitsOfFirstFixedSurface',
#  'nameOfFirstFixedSurface',
#  'scaleFactorOfFirstFixedSurface',
#  'scaledValueOfFirstFixedSurface',
#  'typeOfSecondFixedSurface',
#  'unitsOfSecondFixedSurface',
#  'nameOfSecondFixedSurface',
#  'scaleFactorOfSecondFixedSurface',
#  'scaledValueOfSecondFixedSurface',
#  'pressureUnits',
#  'typeOfLevel',
#  'level',
#  'bottomLevel',
#  'topLevel',
#  'tempPressureUnits',
#  'paramIdECMF',
#  'paramId',
#  'shortNameECMF',
#  'shortName',
#  'unitsECMF',
#  'units',
#  'nameECMF',
#  'name',
#  'cfNameECMF',
#  'cfName',
#  'cfVarNameECMF',
#  'cfVarName',
#  'modelName',
#  'ifsParam',
#  'PVPresent',
#  'deletePV',
#  'lengthOfHeaders',
#  'sectionNumber',
#  'section5Length',
#  'numberOfSection',
#  'numberOfValues',
#  'dataRepresentationTemplateNumber',
#  'packingType',
#  'referenceValue',
#  'referenceValueError',
#  'binaryScaleFactor',
#  'decimalScaleFactor',
#  'bitsPerValue',
#  'typeOfOriginalFieldValues',
#  'sectionNumber',
#  'section6Length',
#  'numberOfSection',
#  'bitMapIndicator',
#  'bitmapPresent',
#  'sectionNumber',
#  'section7Length',
#  'numberOfSection',
#  'codedValues',
#  'values',
#  'packingError',
#  'unpackedError',
#  'maximum',
#  'minimum',
#  'average',
#  'numberOfMissing',
#  'standardDeviation',
#  'skewness',
#  'kurtosis',
#  'isConstant',
#  'changeDecimalPrecision',
#  'decimalPrecision',
#  'setBitsPerValue',
#  'getNumberOfValues',
#  'scaleValuesBy',
#  'offsetValuesBy',
#  'productType',
#  'section8Length',
#  'analDate',
#  'validDate']

# %%
grbs.rewind() # rewind the iterator
def grb_to_grid(grb_obj):
    #Takes a single grb object containing multiple levels (ice data has only one level) and/or dates
    #Assumes same time and levels. Compiles to a grid
    n_levels = len(grb_obj)
    levels = np.array([grb_element['level'] for grb_element in grb_obj])
    dates = np.array([grb_element.validDate for grb_element in grb_obj])
    indexes = np.argsort(levels)[::-1] # highest pressure first
    grid = np.zeros([n_levels, grb_obj[0].values.shape[0], grb_obj[1].values.shape[1]])
    for i in range(n_levels):
        grid[i,:,:] = grb_obj[indexes[i]].values
    grid_dict = {'data' : grid, 'units' : grb_obj[0]['units'],
                 'levels' : levels[indexes], 'dates': dates}
    return grid_dict

# %%
grb = grbs.select(name='Sea-ice cover')
grb_concentration = grb_to_grid(grb)

# %%
#print(grb_concentration)
print(grb_concentration['units'])
print(grb_concentration['levels'][10])
# Out:
# (0 - 1)
# 0

# %%
grbs.rewind() # rewind the iterator
for grb in grbs:
    lats, lons = grb.latlons()  # get the lats and lons for the grid.
print(lats, lons)
#lats, lons = grb.latlons()  # get the lats and lons for the grid.
# Out:
# [[ 56.992486  56.992486  56.992486 ...,  56.992486  56.992486  56.992486]
#  [ 57.009185  57.009185  57.009185 ...,  57.009185  57.009185  57.009185]
#  [ 57.025884  57.025884  57.025884 ...,  57.025884  57.025884  57.025884]
#  ...,
#  [ 65.976548  65.976548  65.976548 ...,  65.976548  65.976548  65.976548]
#  [ 65.993247  65.993247  65.993247 ...,  65.993247  65.993247  65.993247]
#  [ 66.009946  66.009946  66.009946 ...,  66.009946  66.009946  66.009946]] [[ 16.717       16.75041063  16.78382126 ...,  30.24830474  30.28171537
#    30.315126  ]
#  [ 16.717       16.75041063  16.78382126 ...,  30.24830474  30.28171537
#    30.315126  ]
#  [ 16.717       16.75041063  16.78382126 ...,  30.24830474  30.28171537
#    30.315126  ]
#  ...,
#  [ 16.717       16.75041063  16.78382126 ...,  30.24830474  30.28171537
#    30.315126  ]
#  [ 16.717       16.75041063  16.78382126 ...,  30.24830474  30.28171537
#    30.315126  ]
#  [ 16.717       16.75041063  16.78382126 ...,  30.24830474  30.28171537
#    30.315126  ]]

# %%
def plot_grb(grb, datetime):
    f = plt.figure(figsize=[12,10])
    m = Basemap(llcrnrlon = lons.min(),llcrnrlat = lats.min(), urcrnrlon = lons.max(),
               urcrnrlat = lats.max(),
               projection = 'mill', area_thresh =1000 ,
               resolution='l')
    x, y = m(lons, lats)
    #palette = plt.cm.jet
    #palette.set_bad(ax.get_axis_bgcolor(), 1.0)
    my_mesh = m.pcolor(x, y, grb, cmap='jet')
    my_coast = m.drawcoastlines(linewidth=1)
    t = plt.title(datetime)
    plt.colorbar()

# %%
for i in range(0 , 4):
    test = grb_concentration['data'][i]
    # Change null's to 0
    test[test == 9999.0] = 0
    plot_grb(test, grb_concentration['dates'][i])

# %%
f = plt.figure(figsize=[12,10])
m = Basemap(llcrnrlon = lons.min(),llcrnrlat = lats.min(), urcrnrlon = lons.max(),
           urcrnrlat = lats.max(),
           projection = 'mill', area_thresh =1000 ,
           resolution='l')
x, y = m(lons, lats)
my_mesh = m.pcolor(x, y, grb_concentration['data'][0], vmin=0.1,vmax=1, cmap='jet')
my_coast = m.drawcoastlines(linewidth=1.)
plt.colorbar()

# %%
# Get ice thicknesses and visualize the first 4 forecasts
grb = grbs.select(name='Sea-ice thickness')
grb_thickness = grb_to_grid(grb)
print(grb_thickness['units'])
for i in range(0 , 4):
    # Change null's to 0
    test = grb_thickness['data'][i]
    test[test == 9999.0] = 0
    plot_grb(test, grb_thickness['dates'][i])
# Out:
# m
